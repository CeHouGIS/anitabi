# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from glob import glob

# %%
data = pd.read_pickle('/data_nas/cehou/anitabi/data/anime_data_to_use.pkl')
data_gdf = gpd.GeoDataFrame(data, geometry=gpd.points_from_xy(data['lon'], data['lat']))
data.rename(columns={'id':'anime_img_id'}, inplace=True)

# %%
idx = 12345
img_path = f"/data_nas/cehou/anitabi/metadata/{data.loc[idx,'anime_id']}/anime_imgs/{data.loc[idx,'id']}.jpg"
# plt.imshow(Image.open(img_path))

# %%
glob("/data_nas/cehou/anitabi/realworld_svi/*")
# Out:
# ['/data_nas/cehou/anitabi/realworld_svi/pano_2025-01-19_03-27-05_20962.p',
#  '/data_nas/cehou/anitabi/realworld_svi/pano_2025-01-19_03-32-41_20962.p',
#  '/data_nas/cehou/anitabi/realworld_svi/pano_2025-01-19_04-22-19_20962.p']

# %%
all_data.drop_duplicates(subset=['panoid','lat','lon'], inplace=True)
all_data.reset_index(drop=True, inplace=True)

# %%
all_data.drop_duplicates('panoid')
# Out:
#                        panoid        lat         lon    year  month   id
# 0      6CzvA6RCXn7Bq-4HlwGZKg  35.702643  139.400981  2016.0   11.0   10
# 1      ScuMdboMVj5_o2P3abKVJg  43.079168  141.298109  2019.0    5.0   11
# 2      _3NQpkQVjSCjEHIL7-qKkg  43.079223  141.298017  2016.0    7.0   11
# 3      fZyvGdP-76x5FxTEWYcYJA  43.079113  141.298203  2015.0    7.0   11
# 4      qhcFWum5-dL2BkCgeCsvcA  43.079276  141.297925  2014.0    7.0   11
# ...                       ...        ...         ...     ...    ...  ...
# 79717  Cjp3MNmlfubTkTiSkrI1Yg  43.037947  141.351440  2010.0    8.0    7
# 79718  bF-UYu9skPXroq67V60qqg  43.037955  141.351565  2024.0    8.0    7
# 79719  9T7rGe_6XtbNASgkhSRXRA  35.703297  139.400274  2016.0   11.0    8
# 79720  wNRLqPWIVNyuIw-Myqu9dA  35.703948  139.398792  2016.0   11.0    9
# 79721  mnDkcVIWyirhrifzthKEOQ  35.660563  139.697643  2018.0    4.0  604
#
# [79722 rows x 6 columns]

# %%
all_data.to_pickle('/data_nas/cehou/anitabi/realworld_svi/svi_metadata.pkl')
